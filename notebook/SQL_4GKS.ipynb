# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numpy
#   Using cached numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# Collecting pandas
#   Using cached pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.37-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas->pandasql) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas->pandasql) (2.8.2)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.6/156.6 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26768 sha256=d5ed3f184b4e6354c576420aa0e889a53e5cb0d97e6713cf8255a3cf009a5e7e
#   Stored in directory: /home/gitpod/.cache/pip/wheels/ed/8f/46/a383923333728744f01ba24adbd8e364f2cb9470a8b8e5b9ff
# Successfully built pandasql
# Installing collected packages: numpy, greenlet, sqlalchemy, pandas, pandasql
# Successfully installed greenlet-1.1.2 numpy-1.22.4 pandas-1.4.2 pandasql-0.7.3 sqlalchemy-1.4.37
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
from pandasql import sqldf
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
sqldf("select * from df limit 10")
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                 NaN         None       None                None  ...
# 1                 NaN         None       None                None  ...
# 2                 NaN         None       None                None  ...
# 3                 NaN         None       None                None  ...
# 4                 NaN         None       None                None  ...
# 5               0.714         None       None                None  ...
# 6               0.714         None       None                None  ...
# 7               0.000         None       None                None  ...
# 8               0.000         None       None                None  ...
# 9               0.000         None       None                None  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0            None          None                  37.746
# 1            None          None                  37.746
# 2            None          None                  37.746
# 3            None          None                  37.746
# 4            None          None                  37.746
# 5            None          None                  37.746
# 6            None          None                  37.746
# 7            None          None                  37.746
# 8            None          None                  37.746
# 9            None          None                  37.746
#
#   hospital_beds_per_thousand life_expectancy human_development_index  \
# 0                        0.5           64.83                   0.511
# 1                        0.5           64.83                   0.511
# 2                        0.5           64.83                   0.511
# 3                        0.5           64.83                   0.511
# 4                        0.5           64.83                   0.511
# 5                        0.5           64.83                   0.511
# 6                        0.5           64.83                   0.511
# 7                        0.5           64.83                   0.511
# 8                        0.5           64.83                   0.511
# 9                        0.5           64.83                   0.511
#
#   excess_mortality_cumulative_absolute excess_mortality_cumulative  \
# 0                                 None                        None
# 1                                 None                        None
# 2                                 None                        None
# 3                                 None                        None
# 4                                 None                        None
# 5                                 None                        None
# 6                                 None                        None
# 7                                 None                        None
# 8                                 None                        None
# 9                                 None                        None
#
#   excess_mortality excess_mortality_cumulative_per_million
# 0             None                                    None
# 1             None                                    None
# 2             None                                    None
# 3             None                                    None
# 4             None                                    None
# 5             None                                    None
# 6             None                                    None
# 7             None                                    None
# 8             None                                    None
# 9             None                                    None
#
# [10 rows x 67 columns]

# %%
sqldf("select location, new_cases from df limit 10")
# Out:
#       location  new_cases
# 0  Afghanistan        5.0
# 1  Afghanistan        0.0
# 2  Afghanistan        0.0
# 3  Afghanistan        0.0
# 4  Afghanistan        0.0
# 5  Afghanistan        0.0
# 6  Afghanistan        0.0
# 7  Afghanistan        0.0
# 8  Afghanistan        0.0
# 9  Afghanistan        0.0

# %%
sqldf("SELECT location, new_cases FROM df WHERE location='Uruguay'")
# Out:
#     location  new_cases
# 0    Uruguay        4.0
# 1    Uruguay        2.0
# 2    Uruguay        2.0
# 3    Uruguay       21.0
# 4    Uruguay       21.0
# ..       ...        ...
# 817  Uruguay        NaN
# 818  Uruguay        NaN
# 819  Uruguay        NaN
# 820  Uruguay        NaN
# 821  Uruguay        NaN
#
# [822 rows x 2 columns]

# %%
sqldf("SELECT location, new_cases, date FROM df WHERE location='Uruguay' LIMIT 10")
# Out:
#   location  new_cases        date
# 0  Uruguay        4.0  2020-03-13
# 1  Uruguay        2.0  2020-03-14
# 2  Uruguay        2.0  2020-03-15
# 3  Uruguay       21.0  2020-03-16
# 4  Uruguay       21.0  2020-03-17
# 5  Uruguay       29.0  2020-03-18
# 6  Uruguay       15.0  2020-03-19
# 7  Uruguay       16.0  2020-03-20
# 8  Uruguay       25.0  2020-03-21
# 9  Uruguay       23.0  2020-03-22

# %%
sqldf("SELECT location, new_cases, date FROM df WHERE location='Uruguay' ORDER BY date DESC LIMIT 10")
# Out:
#   location  new_cases        date
# 0  Uruguay        NaN  2022-06-12
# 1  Uruguay        NaN  2022-06-11
# 2  Uruguay        NaN  2022-06-10
# 3  Uruguay        NaN  2022-06-09
# 4  Uruguay        NaN  2022-06-08
# 5  Uruguay     9184.0  2022-06-07
# 6  Uruguay        0.0  2022-06-06
# 7  Uruguay        0.0  2022-06-05
# 8  Uruguay        0.0  2022-06-04
# 9  Uruguay        0.0  2022-06-03
